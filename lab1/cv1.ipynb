# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(im[:,:,0])
plt.subplot(222)
plt.imshow(im[:,:,1])
plt.subplot(223)
plt.imshow(im[:,:,2])
plt.subplot(224)
plt.imshow(im)
plt.show()

# %%
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure()
plt.subplot(121)
plt.plot(im[:,1000,1])
plt.subplot(122)
plt.imshow(im)
plt.show()

# %%
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))
plt.plot()

plt.imshow(im[250:600, 850:1250,:])



plt.show()

# %%
im = pltimg.imread('.\\6_26.jpg')
im2 = pltimg.imread('.\\6_26.jpg')
im3 = pltimg.imread('.\\6_26.jpg')
im4 = pltimg.imread('.\\6_26.jpg')
im5 = pltimg.imread('.\\6_26.jpg')
im6 = pltimg.imread('.\\6_26.jpg')
im7 = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))



im2[:,:,1] = im[:,:,0]
im2[:,:,2] = im[:,:,1]
im2[:,:,0] = im[:,:,2]

im3[:,:,2] = im[:,:,0]
im3[:,:,1] = im[:,:,1]
im3[:,:,0] = im[:,:,2]

im4[:,:,2] = im[:,:,0]
im4[:,:,0] = im[:,:,1]
im4[:,:,1] = im[:,:,2]

im5[:,:,1] = im[:,:,0]
im5[:,:,2] = im[:,:,1]
im5[:,:,0] = im[:,:,2]

im6[:,:,1] = im[:,:,0]
im6[:,:,0] = im[:,:,1]
im6[:,:,2] = im[:,:,2]

im7[:,:,0] = im[:,:,0]
im7[:,:,2] = im[:,:,1]
im7[:,:,1] = im[:,:,2]

im8[:,:, ]



plt.subplot(321)
plt.imshow(im2)
plt.subplot(322)
plt.imshow(im3)
plt.subplot(323)
plt.imshow(im4)
plt.subplot(324)
plt.imshow(im)
plt.subplot(325)
plt.imshow(im6)
plt.subplot(326)
plt.imshow(im7)
plt.show()

# %%
im = pltimg.imread('.\\6_26.jpg')
im2 = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))
plt.plot()

im[0:350, 0:400,] = im2[250:600, 850:1250,:]

plt.imshow(im)



plt.show()
